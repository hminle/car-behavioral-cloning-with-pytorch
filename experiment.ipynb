# %% [markdown]
# # Experiment:
#
# Explore the dataset and build a model that can accept the data

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from utils import *
import argparse
import os

# %%
import torch
import torch.nn as nn
import torch.nn.init as init
from torch.autograd import Variable
import torch.optim as optim
from torch.utils.data import DataLoader
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torchvision.utils import save_image
#from torchnet.meter import AverageValueMeter
import torch.backends.cudnn as cudnn

# %%
from model import *

# %%
parser = {
    'data_dir': './selfdrivingcar-data/lap1/',
    'nb_epoch': 50,
    'test_size': 64,
    'learning_rate': 0.0001,
    'keep_prob': 136,
    'samples_per_epoch': 64,
    'batch_size': 100,
    'save_best_only': 64,
    'cuda': True,
    'seed': 7
}
args = argparse.Namespace(**parser)
args.cuda = args.cuda and torch.cuda.is_available()

torch.manual_seed(args.seed)
if args.cuda:
    torch.cuda.manual_seed(args.seed)

# %%
def load_data(args):
    """
    Load training data and split it into training and validation set
    """
    #reads CSV file into a single dataframe variable
    data_df = pd.read_csv(os.path.join(os.getcwd(), args.data_dir, 'driving_log.csv'), names=['center', 'left', 'right', 'steering', 'throttle', 'reverse', 'speed'])

    #yay dataframes, we can select rows and columns by their names
    #we'll store the camera images as our input data
    X = data_df[['center', 'left', 'right']].values
    #and our steering commands as our output data
    y = data_df['steering'].values

    #now we can split the data into a training (80), testing(20), and validation set
    #thanks scikit learn
    X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=args.test_size, random_state=0)

    return X_train, X_valid, y_train, y_valid

# %%
X_train, X_valid, y_train, y_valid = load_data(args)

# %%
transformations = transforms.Compose([transforms.ToTensor(),
                                     transforms.Normalize((127.5, 127.5, 127.5), (127.5, 127.5, 127.5))
                                     ])

# %%
train_set = CarDataset(X_train, y_train, args.data_dir, True, transformations)

# %%
train_loader = DataLoader(train_set, batch_size=args.batch_size, shuffle=True, num_workers=4)

# %% [markdown]
# test_image = 0
# for data, steer in train_loader:
#     print(data[0])
#     print(steer[0])
#     test_image = data[0]
#     break

# %% [markdown]
# # Build Model

# %% [markdown]
#  ### NVIDIA model used
#     Image normalization to avoid saturation and make gradients work better.
#     Convolution: 5x5, filter: 24, strides: 2x2, activation: ELU
#     Convolution: 5x5, filter: 36, strides: 2x2, activation: ELU
#     Convolution: 5x5, filter: 48, strides: 2x2, activation: ELU
#     Convolution: 3x3, filter: 64, strides: 1x1, activation: ELU
#     Convolution: 3x3, filter: 64, strides: 1x1, activation: ELU
#     Drop out (0.5)
#     Fully connected: neurons: 100, activation: ELU
#     Fully connected: neurons: 50, activation: ELU
#     Fully connected: neurons: 10, activation: ELU
#     Fully connected: neurons: 1 (output)
#
#     the convolution layers are meant to handle feature engineering
#     the fully connected layer for predicting the steering angle.
#     dropout avoids overfitting
#     ELU(Exponential linear unit) function takes care of the Vanishing gradient problem.

# %% [markdown]
# # Define Train

# %%
# Training
def train(epoch, net, dataloader, optimizer, criterion, use_cuda):
    print('\nEpoch: %d' % epoch)
    net.train()
    train_loss = 0
    correct = 0
    total = 0
    for batch_idx, (inputs, targets) in enumerate(dataloader):
        optimizer.zero_grad()
        inputs, targets = Variable(inputs), Variable(targets.float())
        if use_cuda:
            inputs, targets = inputs.cuda(), targets.cuda()
        outputs = net(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()

        train_loss += loss
# Loss: 0.046
# Loss: 0.057
# Loss: 0.056
# Loss: 0.051
# Loss: 0.050
# Loss: 0.051
# Loss: 0.052
# Loss: 0.050
# Loss: 0.051
# Loss: 0.051
# Loss: 0.050
# Loss: 0.049
# Loss: 0.048
# Loss: 0.049
#
# Epoch: 48
# Loss: 0.032
# Loss: 0.039
# Loss: 0.040
# Loss: 0.039
# Loss: 0.045
# Loss: 0.044
# Loss: 0.046
# Loss: 0.044
# Loss: 0.048
# Loss: 0.047
# Loss: 0.047
# Loss: 0.048
# Loss: 0.049
# Loss: 0.048
#
# Epoch: 49
# Loss: 0.033
# Loss: 0.038
# Loss: 0.042
# Loss: 0.041
# Loss: 0.044
# Loss: 0.046
# Loss: 0.045
# Loss: 0.046
# Loss: 0.049
# Loss: 0.048
# Loss: 0.052
# Loss: 0.052
# Loss: 0.050
# Loss: 0.051

# %% [markdown]
# ## Save Model

# %%
state = {
        'net': net.module if args.cuda else net,
        }

# %%
torch.save(state, './model.h5')

# %%
data_df = pd.read_csv(os.path.join(os.getcwd(), args.data_dir, 'driving_log.csv'), names=['center', 'left', 'right', 'steering', 'throttle', 'reverse', 'speed'])

# %%
data_df
# Out:
#                                                  center  \
# 0     /mnt/data/github_dir/car-behavioral-cloning-wi...
# 1     /mnt/data/github_dir/car-behavioral-cloning-wi...
# 2     /mnt/data/github_dir/car-behavioral-cloning-wi...
# 3     /mnt/data/github_dir/car-behavioral-cloning-wi...
# 4     /mnt/data/github_dir/car-behavioral-cloning-wi...
# 5     /mnt/data/github_dir/car-behavioral-cloning-wi...
# 6     /mnt/data/github_dir/car-behavioral-cloning-wi...
# 7     /mnt/data/github_dir/car-behavioral-cloning-wi...
# 8     /mnt/data/github_dir/car-behavioral-cloning-wi...
# 9     /mnt/data/github_dir/car-behavioral-cloning-wi...
# 10    /mnt/data/github_dir/car-behavioral-cloning-wi...
# 11    /mnt/data/github_dir/car-behavioral-cloning-wi...
# 12    /mnt/data/github_dir/car-behavioral-cloning-wi...
# 13    /mnt/data/github_dir/car-behavioral-cloning-wi...
# 14    /mnt/data/github_dir/car-behavioral-cloning-wi...
# 15    /mnt/data/github_dir/car-behavioral-cloning-wi...
# 16    /mnt/data/github_dir/car-behavioral-cloning-wi...
# 17    /mnt/data/github_dir/car-behavioral-cloning-wi...
# 18    /mnt/data/github_dir/car-behavioral-cloning-wi...
# 19    /mnt/data/github_dir/car-behavioral-cloning-wi...
# 20    /mnt/data/github_dir/car-behavioral-cloning-wi...
# 21    /mnt/data/github_dir/car-behavioral-cloning-wi...
# 22    /mnt/data/github_dir/car-behavioral-cloning-wi...
# 23    /mnt/data/github_dir/car-behavioral-cloning-wi...
# 24    /mnt/data/github_dir/car-behavioral-cloning-wi...
# 25    /mnt/data/github_dir/car-behavioral-cloning-wi...
# 26    /mnt/data/github_dir/car-behavioral-cloning-wi...
# 27    /mnt/data/github_dir/car-behavioral-cloning-wi...
# 28    /mnt/data/github_dir/car-behavioral-cloning-wi...
# 29    /mnt/data/github_dir/car-behavioral-cloning-wi...
# ...                                                 ...
# 1392  /mnt/data/github_dir/car-behavioral-cloning-wi...
# 1393  /mnt/data/github_dir/car-behavioral-cloning-wi...
# 1394  /mnt/data/github_dir/car-behavioral-cloning-wi...
# 1395  /mnt/data/github_dir/car-behavioral-cloning-wi...
# 1396  /mnt/data/github_dir/car-behavioral-cloning-wi...
# 1397  /mnt/data/github_dir/car-behavioral-cloning-wi...
# 1398  /mnt/data/github_dir/car-behavioral-cloning-wi...
# 1399  /mnt/data/github_dir/car-behavioral-cloning-wi...
# 1400  /mnt/data/github_dir/car-behavioral-cloning-wi...
# 1401  /mnt/data/github_dir/car-behavioral-cloning-wi...
# 1402  /mnt/data/github_dir/car-behavioral-cloning-wi...
# 1403  /mnt/data/github_dir/car-behavioral-cloning-wi...
# 1404  /mnt/data/github_dir/car-behavioral-cloning-wi...
# 1405  /mnt/data/github_dir/car-behavioral-cloning-wi...
# 1406  /mnt/data/github_dir/car-behavioral-cloning-wi...
# 1407  /mnt/data/github_dir/car-behavioral-cloning-wi...
# 1408  /mnt/data/github_dir/car-behavioral-cloning-wi...
# 1409  /mnt/data/github_dir/car-behavioral-cloning-wi...
# 1410  /mnt/data/github_dir/car-behavioral-cloning-wi...
# 1411  /mnt/data/github_dir/car-behavioral-cloning-wi...
# 1412  /mnt/data/github_dir/car-behavioral-cloning-wi...
# 1413  /mnt/data/github_dir/car-behavioral-cloning-wi...
# 1414  /mnt/data/github_dir/car-behavioral-cloning-wi...
# 1415  /mnt/data/github_dir/car-behavioral-cloning-wi...
# 1416  /mnt/data/github_dir/car-behavioral-cloning-wi...
# 1417  /mnt/data/github_dir/car-behavioral-cloning-wi...
# 1418  /mnt/data/github_dir/car-behavioral-cloning-wi...
# 1419  /mnt/data/github_dir/car-behavioral-cloning-wi...
# 1420  /mnt/data/github_dir/car-behavioral-cloning-wi...
# 1421  /mnt/data/github_dir/car-behavioral-cloning-wi...
#
#                                                    left  \
# 0      /mnt/data/github_dir/car-behavioral-cloning-w...
# 1      /mnt/data/github_dir/car-behavioral-cloning-w...
# 2      /mnt/data/github_dir/car-behavioral-cloning-w...
# 3      /mnt/data/github_dir/car-behavioral-cloning-w...
# 4      /mnt/data/github_dir/car-behavioral-cloning-w...
# 5      /mnt/data/github_dir/car-behavioral-cloning-w...
# 6      /mnt/data/github_dir/car-behavioral-cloning-w...
# 7      /mnt/data/github_dir/car-behavioral-cloning-w...
# 8      /mnt/data/github_dir/car-behavioral-cloning-w...
# 9      /mnt/data/github_dir/car-behavioral-cloning-w...
# 10     /mnt/data/github_dir/car-behavioral-cloning-w...
# 11     /mnt/data/github_dir/car-behavioral-cloning-w...
# 12     /mnt/data/github_dir/car-behavioral-cloning-w...
# 13     /mnt/data/github_dir/car-behavioral-cloning-w...
# 14     /mnt/data/github_dir/car-behavioral-cloning-w...
# 15     /mnt/data/github_dir/car-behavioral-cloning-w...
# 16     /mnt/data/github_dir/car-behavioral-cloning-w...
# 17     /mnt/data/github_dir/car-behavioral-cloning-w...
# 18     /mnt/data/github_dir/car-behavioral-cloning-w...
# 19     /mnt/data/github_dir/car-behavioral-cloning-w...
# 20     /mnt/data/github_dir/car-behavioral-cloning-w...
# 21     /mnt/data/github_dir/car-behavioral-cloning-w...
# 22     /mnt/data/github_dir/car-behavioral-cloning-w...
# 23     /mnt/data/github_dir/car-behavioral-cloning-w...
# 24     /mnt/data/github_dir/car-behavioral-cloning-w...
# 25     /mnt/data/github_dir/car-behavioral-cloning-w...
# 26     /mnt/data/github_dir/car-behavioral-cloning-w...
# 27     /mnt/data/github_dir/car-behavioral-cloning-w...
# 28     /mnt/data/github_dir/car-behavioral-cloning-w...
# 29     /mnt/data/github_dir/car-behavioral-cloning-w...
# ...                                                 ...
# 1392   /mnt/data/github_dir/car-behavioral-cloning-w...
# 1393   /mnt/data/github_dir/car-behavioral-cloning-w...
# 1394   /mnt/data/github_dir/car-behavioral-cloning-w...
# 1395   /mnt/data/github_dir/car-behavioral-cloning-w...
# 1396   /mnt/data/github_dir/car-behavioral-cloning-w...
# 1397   /mnt/data/github_dir/car-behavioral-cloning-w...
# 1398   /mnt/data/github_dir/car-behavioral-cloning-w...
# 1399   /mnt/data/github_dir/car-behavioral-cloning-w...
# 1400   /mnt/data/github_dir/car-behavioral-cloning-w...
# 1401   /mnt/data/github_dir/car-behavioral-cloning-w...
# 1402   /mnt/data/github_dir/car-behavioral-cloning-w...
# 1403   /mnt/data/github_dir/car-behavioral-cloning-w...
# 1404   /mnt/data/github_dir/car-behavioral-cloning-w...
# 1405   /mnt/data/github_dir/car-behavioral-cloning-w...
# 1406   /mnt/data/github_dir/car-behavioral-cloning-w...
# 1407   /mnt/data/github_dir/car-behavioral-cloning-w...
# 1408   /mnt/data/github_dir/car-behavioral-cloning-w...
# 1409   /mnt/data/github_dir/car-behavioral-cloning-w...
# 1410   /mnt/data/github_dir/car-behavioral-cloning-w...
# 1411   /mnt/data/github_dir/car-behavioral-cloning-w...
# 1412   /mnt/data/github_dir/car-behavioral-cloning-w...
# 1413   /mnt/data/github_dir/car-behavioral-cloning-w...
# 1414   /mnt/data/github_dir/car-behavioral-cloning-w...
# 1415   /mnt/data/github_dir/car-behavioral-cloning-w...
# 1416   /mnt/data/github_dir/car-behavioral-cloning-w...
# 1417   /mnt/data/github_dir/car-behavioral-cloning-w...
# 1418   /mnt/data/github_dir/car-behavioral-cloning-w...
# 1419   /mnt/data/github_dir/car-behavioral-cloning-w...
# 1420   /mnt/data/github_dir/car-behavioral-cloning-w...
# 1421   /mnt/data/github_dir/car-behavioral-cloning-w...
#
#                                                   right  steering  throttle  \
# 0      /mnt/data/github_dir/car-behavioral-cloning-w...  0.000000  0.000000
# 1      /mnt/data/github_dir/car-behavioral-cloning-w...  0.000000  0.000000
# 2      /mnt/data/github_dir/car-behavioral-cloning-w...  0.000000  0.000000
# 3      /mnt/data/github_dir/car-behavioral-cloning-w...  0.000000  0.000000
# 4      /mnt/data/github_dir/car-behavioral-cloning-w...  0.000000  0.000000
# 5      /mnt/data/github_dir/car-behavioral-cloning-w...  0.000000  0.000000
# 6      /mnt/data/github_dir/car-behavioral-cloning-w...  0.000000  0.000000
# 7      /mnt/data/github_dir/car-behavioral-cloning-w...  0.000000  0.000000
# 8      /mnt/data/github_dir/car-behavioral-cloning-w...  0.000000  0.000000
# 9      /mnt/data/github_dir/car-behavioral-cloning-w...  0.000000  0.000000
# 10     /mnt/data/github_dir/car-behavioral-cloning-w...  0.000000  0.000000
# 11     /mnt/data/github_dir/car-behavioral-cloning-w...  0.000000  0.000000
# 12     /mnt/data/github_dir/car-behavioral-cloning-w...  0.000000  0.000000
# 13     /mnt/data/github_dir/car-behavioral-cloning-w...  0.000000  0.000000
# 14     /mnt/data/github_dir/car-behavioral-cloning-w...  0.000000  0.162747
# 15     /mnt/data/github_dir/car-behavioral-cloning-w... -0.082641  0.473700
# 16     /mnt/data/github_dir/car-behavioral-cloning-w... -0.358062  0.561598
# 17     /mnt/data/github_dir/car-behavioral-cloning-w...  0.000000  0.196180
# 18     /mnt/data/github_dir/car-behavioral-cloning-w...  0.000000  0.000000
# 19     /mnt/data/github_dir/car-behavioral-cloning-w...  0.000000  0.000000
# 20     /mnt/data/github_dir/car-behavioral-cloning-w...  0.000000  0.331437
# 21     /mnt/data/github_dir/car-behavioral-cloning-w...  0.000000  0.623706
# 22     /mnt/data/github_dir/car-behavioral-cloning-w...  0.000000  0.994407
# 23     /mnt/data/github_dir/car-behavioral-cloning-w...  0.000000  1.000000
# 24     /mnt/data/github_dir/car-behavioral-cloning-w... -0.270609  1.000000
# 25     /mnt/data/github_dir/car-behavioral-cloning-w...  0.000000  1.000000
# 26     /mnt/data/github_dir/car-behavioral-cloning-w...  0.000000  1.000000
# 27     /mnt/data/github_dir/car-behavioral-cloning-w... -0.076020  1.000000
# 28     /mnt/data/github_dir/car-behavioral-cloning-w... -0.146454  1.000000
# 29     /mnt/data/github_dir/car-behavioral-cloning-w...  0.000000  1.000000
# ...                                                 ...       ...       ...
# 1392   /mnt/data/github_dir/car-behavioral-cloning-w...  0.745810  0.000000
# 1393   /mnt/data/github_dir/car-behavioral-cloning-w...  0.432880  0.000000
# 1394   /mnt/data/github_dir/car-behavioral-cloning-w...  0.124156  0.000000
# 1395   /mnt/data/github_dir/car-behavioral-cloning-w...  0.000000  0.000000
# 1396   /mnt/data/github_dir/car-behavioral-cloning-w...  0.000000  0.373260
# 1397   /mnt/data/github_dir/car-behavioral-cloning-w...  0.000000  0.693666
# 1398   /mnt/data/github_dir/car-behavioral-cloning-w... -0.036363  0.969258
# 1399   /mnt/data/github_dir/car-behavioral-cloning-w... -0.398541  0.960982
# 1400   /mnt/data/github_dir/car-behavioral-cloning-w... -0.720093  0.639430
# 1401   /mnt/data/github_dir/car-behavioral-cloning-w... -0.993816  0.365707
# 1402   /mnt/data/github_dir/car-behavioral-cloning-w... -0.788782  0.000000
# 1403   /mnt/data/github_dir/car-behavioral-cloning-w... -0.481279  0.000000
# 1404   /mnt/data/github_dir/car-behavioral-cloning-w... -0.173581  0.000000
# 1405   /mnt/data/github_dir/car-behavioral-cloning-w...  0.000000  0.000000
# 1406   /mnt/data/github_dir/car-behavioral-cloning-w...  0.210021  0.000000
# 1407   /mnt/data/github_dir/car-behavioral-cloning-w...  0.481596  0.000000
# 1408   /mnt/data/github_dir/car-behavioral-cloning-w...  0.830247  0.000000
# 1409   /mnt/data/github_dir/car-behavioral-cloning-w...  1.000000  0.000000
# 1410   /mnt/data/github_dir/car-behavioral-cloning-w...  0.619618  0.099831
# 1411   /mnt/data/github_dir/car-behavioral-cloning-w...  0.307423  0.412026
# 1412   /mnt/data/github_dir/car-behavioral-cloning-w...  0.035932  0.683517
# 1413   /mnt/data/github_dir/car-behavioral-cloning-w...  0.000000  1.000000
# 1414   /mnt/data/github_dir/car-behavioral-cloning-w...  0.000000  1.000000
# 1415   /mnt/data/github_dir/car-behavioral-cloning-w...  0.000000  1.000000
# 1416   /mnt/data/github_dir/car-behavioral-cloning-w...  0.046101  1.000000
# 1417   /mnt/data/github_dir/car-behavioral-cloning-w...  0.386628  1.000000
# 1418   /mnt/data/github_dir/car-behavioral-cloning-w...  0.255958  1.000000
# 1419   /mnt/data/github_dir/car-behavioral-cloning-w...  0.000000  0.659365
# 1420   /mnt/data/github_dir/car-behavioral-cloning-w...  0.000000  0.381814
# 1421   /mnt/data/github_dir/car-behavioral-cloning-w...  0.000000  0.011269
#
#       reverse      speed
# 0           0   0.000078
# 1           0   0.000079
# 2           0   0.000079
# 3           0   0.000078
# 4           0   0.000080
# 5           0   0.000079
# 6           0   0.000079
# 7           0   0.000081
# 8           0   0.000079
# 9           0   0.000078
# 10          0   0.000080
# 11          0   0.000079
# 12          0   0.000078
# 13          0   0.000078
# 14          0   0.080651
# 15          0   0.458020
# 16          0   1.133152
# 17          0   1.638163
# 18          0   1.689031
# 19          0   1.672093
# 20          0   1.908140
# 21          0   2.534553
# 22          0   3.723270
# 23          0   4.892786
# 24          0   6.035697
# 25          0   7.407523
# 26          0   8.539804
# 27          0   9.883229
# 28          0  10.967400
# 29          0  12.190270
# ...       ...        ...
# 1392        0  24.855450
# 1393        0  24.408510
# 1394        0  24.321500
# 1395        0  23.869620
# 1396        0  23.815030
# 1397        0  24.564490
# 1398        0  25.215040
# 1399        0  26.266700
# 1400        0  26.747850
# 1401        0  26.654300
# 1402        0  26.224560
# 1403        0  25.998330
# 1404        0  25.722270
# 1405        0  25.409740
# 1406        0  24.846010
# 1407        0  24.597910
# 1408        0  23.846950
# 1409        0  23.085650
# 1410        0  21.300980
# 1411        0  18.849310
# 1412        0  17.015760
# 1413        0  15.225110
# 1414        0  13.595730
# 1415        0  11.713570
# 1416        0  10.435950
# 1417        0   0.120620
# 1418        0   0.052866
# 1419        0   0.031891
# 1420        0   0.016345
# 1421        0   0.004219
#
# [1422 rows x 7 columns]
